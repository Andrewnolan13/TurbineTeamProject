# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
print('Outputs given')
# Out:
# Outputs given

# %%
data_file = r'C:\Users\rsaxe\Downloads\Care_To_Compare\Care_To_Compare\Wind Farm A\Wind Farm A\datasets\0.csv'
df = pd.read_csv(data_file, sep =";")

# %%
df.head()
# Out:
#             time_stamp  asset_id  id train_test  status_type_id  sensor_0_avg  \
# 0  2022-08-03 06:10:00         0   0      train               0          22.0
# 1  2022-08-03 06:20:00         0   1      train               0          22.0
# 2  2022-08-03 06:30:00         0   2      train               0          22.0
# 3  2022-08-03 06:40:00         0   3      train               0          22.0
# 4  2022-08-03 06:50:00         0   4      train               0          22.0
#
#    sensor_1_avg  sensor_2_avg  wind_speed_3_avg  wind_speed_4_avg  ...  \
# 0         302.9         129.4               1.7               1.7  ...
# 1         307.1         133.6               1.7               1.7  ...
# 2         340.6         167.1               0.9               0.9  ...
# 3         124.4         -49.1               1.5               1.5  ...
# 4          66.2        -107.3               1.0               1.0  ...
#
#    sensor_47  sensor_48  sensor_49  sensor_50  sensor_51  sensor_52_avg  \
# 0     -496.0        0.0        0.0    -1280.0     -496.0            0.0
# 1     -490.0        0.0        0.0    -1278.0     -490.0            0.0
# 2     -490.0        0.0        0.0    -1356.0     -490.0            0.0
# 3     -509.0        0.0        0.0    -1274.0     -509.0            0.0
# 4     -499.0        0.0        0.0    -1284.0     -499.0            0.0
#
#    sensor_52_max  sensor_52_min  sensor_52_std  sensor_53_avg
# 0            0.0            0.0            0.0           26.0
# 1            0.0            0.0            0.0           25.0
# 2            0.0            0.0            0.0           25.0
# 3            0.0            0.0            0.0           26.0
# 4            0.0            0.0            0.0           26.0
#
# [5 rows x 86 columns]

# %% [markdown]
# * ``time_stamp``: Time stamps in 10 minute frequency. Time stamps have been anonymized in order to not reveal the identity of the wind farms.
# * ``asset_id``: Wind turbine ID. This can be used to find out which events took place on the same wind turbine. The IDs have also been anonymized.
# * ``id``: An additional ID for each time stamp. This is supposed to prevent confusion with different time formats.
# * ``train_test``: Strings describing whether the timestamp is part of the prediction data or the training data of the dataset.
# * ``status_type``: Status of the wind turbine at the given time stamp. There are 6 different status IDs where status 0 and 2 are considered normal operation:
#   * 0: Normal Operation - The turbine is in normal power production mode
#   * 1: Derated Operation - Derated power generation with a power restriction
#   * 2: Idling - Asset is idling and waits to operate again
#   * 3: Service - Asset is in service mode / service team is at the site
#   * 4: Downtime - Asset is down due a fault or other reasons
#   * 5: Other - Other operational states

# %%
df.tail()
# Out:
#                 time_stamp  asset_id     id  train_test  status_type_id  \
# 54981  2023-08-23 05:30:00         0  54981  prediction               3
# 54982  2023-08-23 05:40:00         0  54982  prediction               3
# 54983  2023-08-23 05:50:00         0  54983  prediction               3
# 54984  2023-08-23 06:00:00         0  54984  prediction               3
# 54985  2023-08-23 06:10:00         0  54985  prediction               3
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 54981          25.0         121.0          24.6               3.3
# 54982          25.0         117.2          20.9               2.8
# 54983          25.0         114.5          18.2               2.7
# 54984          25.0         104.4           8.0               3.1
# 54985          25.0         101.8           5.4               3.4
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 54981               0.0  ...      -17.0        0.0        0.0     -166.0
# 54982               0.0  ...      -17.0        0.0        0.0     -167.0
# 54983               0.0  ...      -17.0        0.0        0.0     -166.0
# 54984               0.0  ...      -17.0        0.0        0.0     -167.0
# 54985               0.0  ...      -17.0        0.0        0.0     -167.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 54981      -17.0            0.0            0.0            0.0            0.0
# 54982      -17.0            0.0            0.0            0.0            0.0
# 54983      -17.0            0.0            0.0            0.0            0.0
# 54984      -17.0            0.0            0.0            0.0            0.0
# 54985      -17.0            0.0            0.0            0.0            0.0
#
#        sensor_53_avg
# 54981           24.0
# 54982           24.0
# 54983           24.0
# 54984           24.0
# 54985           24.0
#
# [5 rows x 86 columns]

# %%
df[df['train_test'] == 'prediction']
# Out:
#                 time_stamp  asset_id     id  train_test  status_type_id  \
# 52148  2023-08-03 06:10:00         0  52148  prediction               0
# 52149  2023-08-03 06:20:00         0  52149  prediction               0
# 52150  2023-08-03 06:30:00         0  52150  prediction               0
# 52151  2023-08-03 06:40:00         0  52151  prediction               0
# 52152  2023-08-03 06:50:00         0  52152  prediction               0
# ...                    ...       ...    ...         ...             ...
# 54981  2023-08-23 05:30:00         0  54981  prediction               3
# 54982  2023-08-23 05:40:00         0  54982  prediction               3
# 54983  2023-08-23 05:50:00         0  54983  prediction               3
# 54984  2023-08-23 06:00:00         0  54984  prediction               3
# 54985  2023-08-23 06:10:00         0  54985  prediction               3
#
#        sensor_0_avg  sensor_1_avg  sensor_2_avg  wind_speed_3_avg  \
# 52148          26.0         186.7        -165.1               1.5
# 52149          26.0         203.4        -148.5               1.1
# 52150          26.0         181.7        -170.2               1.3
# 52151          26.0         156.5         164.6               1.6
# 52152          26.0         155.9         164.0               1.6
# ...             ...           ...           ...               ...
# 54981          25.0         121.0          24.6               3.3
# 54982          25.0         117.2          20.9               2.8
# 54983          25.0         114.5          18.2               2.7
# 54984          25.0         104.4           8.0               3.1
# 54985          25.0         101.8           5.4               3.4
#
#        wind_speed_4_avg  ...  sensor_47  sensor_48  sensor_49  sensor_50  \
# 52148               1.5  ...    -2451.0        0.0        0.0    -1356.0
# 52149               1.1  ...    -2435.0        0.0        0.0    -1368.0
# 52150               1.3  ...    -2411.0        0.0        0.0    -1345.0
# 52151               1.6  ...    -2414.0        0.0        0.0    -1350.0
# 52152               1.6  ...    -2412.0        0.0        0.0    -1359.0
# ...                 ...  ...        ...        ...        ...        ...
# 54981               0.0  ...      -17.0        0.0        0.0     -166.0
# 54982               0.0  ...      -17.0        0.0        0.0     -167.0
# 54983               0.0  ...      -17.0        0.0        0.0     -166.0
# 54984               0.0  ...      -17.0        0.0        0.0     -167.0
# 54985               0.0  ...      -17.0        0.0        0.0     -167.0
#
#        sensor_51  sensor_52_avg  sensor_52_max  sensor_52_min  sensor_52_std  \
# 52148    -2451.0            0.0            0.0            0.0            0.0
# 52149    -2435.0            0.0            0.0            0.0            0.0
# 52150    -2411.0            0.0            0.0            0.0            0.0
# 52151    -2414.0            0.0            0.0            0.0            0.0
# 52152    -2412.0            0.0            0.0            0.0            0.0
# ...          ...            ...            ...            ...            ...
# 54981      -17.0            0.0            0.0            0.0            0.0
# 54982      -17.0            0.0            0.0            0.0            0.0
# 54983      -17.0            0.0            0.0            0.0            0.0
# 54984      -17.0            0.0            0.0            0.0            0.0
# 54985      -17.0            0.0            0.0            0.0            0.0
#
#        sensor_53_avg
# 52148           29.0
# 52149           29.0
# 52150           29.0
# 52151           29.0
# 52152           29.0
# ...              ...
# 54981           24.0
# 54982           24.0
# 54983           24.0
# 54984           24.0
# 54985           24.0
#
# [2838 rows x 86 columns]

# %%
feature_disc = pd.read_csv(r'C:\Users\rsaxe\Downloads\Care_To_Compare\Care_To_Compare\Wind Farm A\Wind Farm A\feature_description.csv', sep = ";")
feature_disc
# Out:
#           sensor_name                  statistics_type  \
# 0            sensor_0                          average
# 1            sensor_1                          average
# 2            sensor_2                          average
# 3        wind_speed_3  maximum,minimum,average,std_dev
# 4        wind_speed_4                          average
# 5            sensor_5  maximum,minimum,std_dev,average
# 6            sensor_6                          average
# 7            sensor_7                          average
# 8            sensor_8                          average
# 9            sensor_9                          average
# 10          sensor_10                          average
# 11          sensor_11                          average
# 12          sensor_12                          average
# 13          sensor_13                          average
# 14          sensor_14                          average
# 15          sensor_15                          average
# 16          sensor_16                          average
# 17          sensor_17                          average
# 18          sensor_18  maximum,minimum,average,std_dev
# 19          sensor_19                          average
# 20          sensor_20                          average
# 21          sensor_21                          average
# 22          sensor_22                          average
# 23          sensor_23                          average
# 24          sensor_24                          average
# 25          sensor_25                          average
# 26          sensor_26                          average
# 27  reactive_power_27  average,maximum,minimum,std_dev
# 28  reactive_power_28  average,maximum,minimum,std_dev
# 29           power_29  maximum,std_dev,average,minimum
# 30           power_30  maximum,std_dev,minimum,average
# 31          sensor_31  average,maximum,minimum,std_dev
# 32          sensor_32                          average
# 33          sensor_33                          average
# 34          sensor_34                          average
# 35          sensor_35                          average
# 36          sensor_36                          average
# 37          sensor_37                          average
# 38          sensor_38                          average
# 39          sensor_39                          average
# 40          sensor_40                          average
# 41          sensor_41                          average
# 42          sensor_42                          average
# 43          sensor_43                          average
# 44          sensor_44                          average
# 45          sensor_45                          average
# 46          sensor_46                          average
# 47          sensor_47                          average
# 48          sensor_48                          average
# 49          sensor_49                          average
# 50          sensor_50                          average
# 51          sensor_51                          average
# 52          sensor_52  minimum,average,std_dev,maximum
# 53          sensor_53                          average
#
#                                           description  unit  is_angle  \
# 0                                 Ambient temperature    �C     False
# 1                             Wind absolute direction     �      True
# 2                             Wind relative direction     �      True
# 3                                           Windspeed   m/s     False
# 4                                 Estimated windspeed   m/s     False
# 5                                         Pitch angle     �      True
# 6                   Temperature in the hub controller    �C     False
# 7           Temperature in the top nacelle controller    �C     False
# 8   Temperature in the choke coils on the VCS-section    �C     False
# 9                        Temperature on the VCP-board    �C     False
# 10               Temperature in the VCS cooling water    �C     False
# 11  Temperature in gearbox bearing on high speed s...    �C     False
# 12                         Temperature oil in gearbox    �C     False
# 13     Temperature in generator bearing 2 (Drive End)    �C     False
# 14  Temperature in generator bearing 1 (Non-Drive ...    �C     False
# 15  Temperature inside generator in stator winding...    �C     False
# 16  Temperature inside generator in stator winding...    �C     False
# 17  Temperature inside generator in stator winding...    �C     False
# 18                     Generator rpm in latest period   rpm     False
# 19              Temperature in the split ring chamber    �C     False
# 20                  Temperature in the busbar section    �C     False
# 21  Temperature measured by the IGBT-driver on the...    �C     False
# 22                          Actual phase displacement   NaN     False
# 23                        Averaged current in phase 1     A     False
# 24                        Averaged current in phase 2     A     False
# 25                        Averaged current in phase 3     A     False
# 26                                     Grid frequency    Hz     False
# 27            Possible grid capacitive reactive power  kVAr     False
# 28             Possible grid inductive reactive power  kVAr     False
# 29                         Possible grid active power    kW     False
# 30                                         Grid power    kW     False
# 31                                Grid reactive power  kVAr     False
# 32                        Averaged voltage in phase 1     V     False
# 33                        Averaged voltage in phase 2     V     False
# 34                        Averaged voltage in phase 3     V     False
# 35  Temperature measured by the IGBT-driver on the...    �C     False
# 36  Temperature measured by the IGBT-driver on the...    �C     False
# 37  Temperature measured by the IGBT-driver on the...    �C     False
# 38             Temperature in HV transformer phase L1    �C     False
# 39             Temperature in HV transformer phase L2    �C     False
# 40             Temperature in HV transformer phase L3    �C     False
# 41                 Temperature oil in hydraulic group    �C     False
# 42                                  Nacelle direction     �      True
# 43                                Nacelle temperature    �C     False
# 44              Active power - generator disconnected    Wh     False
# 45        Active power - generator connected in delta    Wh     False
# 46         Active power - generator connected in star    Wh     False
# 47            Reactive power - generator disconnected  VArh     False
# 48      Reactive power - generator connected in delta  VArh     False
# 49       Reactive power - generator connected in star  VArh     False
# 50                                 Total active power    Wh     False
# 51                               Total reactive power  VArh     False
# 52                                          Rotor rpm   rpm     False
# 53                       Temperature in the nose cone    �C     False
#
#     is_counter
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
# 30       False
# 31       False
# 32       False
# 33       False
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
# 39       False
# 40       False
# 41       False
# 42       False
# 43       False
# 44       False
# 45       False
# 46       False
# 47       False
# 48       False
# 49       False
# 50       False
# 51       False
# 52       False
# 53       False

# %%
pd.DataFrame(df.nunique())
# Out:
#                     0
# time_stamp      54986
# asset_id            1
# id              54986
# train_test          2
# status_type_id      3
# ...               ...
# sensor_52_avg     150
# sensor_52_max     144
# sensor_52_min     127
# sensor_52_std      74
# sensor_53_avg      38
#
# [86 rows x 1 columns]

# %% [markdown]
# * ``time_stamp``: Time stamps in 10 minute frequency. Time stamps have been anonymized in order to not reveal the identity of the wind farms.
# * ``asset_id``: Wind turbine ID. This can be used to find out which events took place on the same wind turbine. The IDs have also been anonymized.
# * ``id``: An additional ID for each time stamp. This is supposed to prevent confusion with different time formats.
# * ``train_test``: Strings describing whether the timestamp is part of the prediction data or the training data of the dataset.
# * ``status_type``: Status of the wind turbine at the given time stamp. There are 6 different status IDs where status 0 and 2 are considered normal operation:
#   * 0: Normal Operation - The turbine is in normal power production mode
#   * 1: Derated Operation - Derated power generation with a power restriction
#   * 2: Idling - Asset is idling and waits to operate again
#   * 3: Service - Asset is in service mode / service team is at the site
#   * 4: Downtime - Asset is down due a fault or other reasons
#   * 5: Other - Other operational states

# %%
print(df['status_type_id'].value_counts())
# Out:
# status_type_id
# 0    41514
# 5    12265
# 3     1207
# Name: count, dtype: int64

# %%
event_dataset = r'C:\Users\rsaxe\Downloads\Care_To_Compare\Care_To_Compare\Wind Farm A\Wind Farm A\event_info.csv'

# %%
event = pd.read_csv(event_dataset, sep =';')

# %%
event.sort_values(by='event_id')
# Out:
#     event_id event_label          event_start  event_start_id  \
# 4          0     anomaly  2023-08-05 06:10:00           52436
# 15         3      normal  2023-04-27 03:00:00           52185
# 8         10     anomaly  2023-10-12 08:40:00           52611
# 13        13      normal  2023-05-02 13:20:00           50859
# 19        14      normal  2023-03-04 14:00:00           52584
# 16        17      normal  2023-11-03 15:20:00           52597
# 1         22     anomaly  2023-08-11 09:50:00           51888
# 14        24      normal  2023-04-26 15:00:00           52720
# 11        25      normal  2023-05-22 06:50:00           52289
# 5         26     anomaly  2023-10-12 10:20:00           52261
# 17        38      normal  2023-06-30 15:40:00           52723
# 6         40     anomaly  2023-12-24 00:00:00           51363
# 7         42     anomaly  2023-09-08 15:50:00           52303
# 9         45     anomaly  2023-04-19 18:10:00           52731
# 21        51      normal  2023-10-07 01:30:00           52331
# 0         68     anomaly  2023-07-29 13:20:00           52063
# 12        69      normal  2023-09-03 00:50:00           52364
# 18        71      normal  2024-01-01 00:00:00           52439
# 2         72     anomaly  2023-10-09 08:40:00           52497
# 3         73     anomaly  2023-06-09 11:40:00           52745
# 10        84     anomaly  2023-09-04 15:30:00           52623
# 20        92      normal  2023-04-05 02:30:00           52437
#
#               event_end  event_end_id          event_description
# 4   2023-08-19 06:10:00         54447  Generator bearing failure
# 15  2023-05-18 01:10:00         55198                        NaN
# 8   2023-10-19 08:40:00         53591            Gearbox failure
# 13  2023-05-23 10:20:00         53865                        NaN
# 19  2023-03-11 18:40:00         53620                        NaN
# 16  2023-11-17 00:40:00         54513                        NaN
# 1   2023-08-18 10:00:00         52892            Hydraulic group
# 14  2023-05-10 11:20:00         54714                        NaN
# 11  2023-06-04 02:30:00         54135                        NaN
# 5   2023-10-19 10:20:00         53269            Hydraulic group
# 17  2023-07-14 07:40:00         54546                        NaN
# 6   2024-01-24 13:00:00         55870  Generator bearing failure
# 7   2023-09-15 15:50:00         53309            Hydraulic group
# 9   2023-04-26 18:10:00         53738            Hydraulic group
# 21  2023-10-18 16:10:00         54003                        NaN
# 0   2023-08-12 13:10:00         54076        Transformer failure
# 12  2023-09-17 00:50:00         54380                        NaN
# 18  2024-01-15 00:00:00         54455                        NaN
# 2   2023-10-16 08:40:00         53505            Gearbox failure
# 3   2023-06-16 11:40:00         53753            Hydraulic group
# 10  2023-09-11 15:30:00         53627            Hydraulic group
# 20  2023-04-14 10:00:00         53778                        NaN
